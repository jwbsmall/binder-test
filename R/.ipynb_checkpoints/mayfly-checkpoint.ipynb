# %%
library("openxlsx")
mayfly <- read.xlsx(xlsxFile = "Rylee/mayfly-data.xlsx", sheet = 1, skipEmptyRows = FALSE)

# %%
mayfly <- mayfly[-c(66),]
mayfly <- subset(mayfly, select=-c(4))
names(mayfly) <- c('v', 'db', 'dh')

# %%
plot(mayfly$v, mayfly$db)
plot(mayfly$v, mayfly$dh)
# Out:
# plot without title
# plot without title
